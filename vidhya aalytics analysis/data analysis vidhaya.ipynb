# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
data  = pd.read_csv("H:/data/vidhaya/test.csv")

# %%
data.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1         11.0                   1
# 1  381111   Male   40                1         28.0                   0
# 2  381112   Male   47                1         28.0                   0
# 3  381113   Male   24                1         27.0                   1
# 4  381114   Male   27                1         28.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                 152.0       53
# 1    1-2 Year            Yes         33762.0                   7.0      111
# 2    1-2 Year            Yes         40050.0                 124.0      199
# 3    < 1 Year            Yes         37356.0                 152.0      187
# 4    < 1 Year             No         59097.0                 152.0      297

# %%
data.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  object
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  float64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  object
#  7   Vehicle_Damage        127037 non-null  object
#  8   Annual_Premium        127037 non-null  float64
#  9   Policy_Sales_Channel  127037 non-null  float64
#  10  Vintage               127037 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 10.7+ MB

# %%
data.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64

# %%
data.hist(figsize = (10,7))
plt.show()

# %%
# correletion of all data
data.corr()
# Out:
#                             id       Age  Driving_License  Region_Code  \
# id                    1.000000 -0.005364        -0.003581    -0.001574
# Age                  -0.005364  1.000000        -0.079374     0.038878
# Driving_License      -0.003581 -0.079374         1.000000     0.002596
# Region_Code          -0.001574  0.038878         0.002596     1.000000
# Previously_Insured   -0.000281 -0.258282         0.012455    -0.022001
# Annual_Premium        0.001386  0.067038        -0.012664    -0.016349
# Policy_Sales_Channel  0.002911 -0.574722         0.040185    -0.041618
# Vintage               0.001225  0.003761        -0.000858     0.001984
#
#                       Previously_Insured  Annual_Premium  \
# id                             -0.000281        0.001386
# Age                            -0.258282        0.067038
# Driving_License                 0.012455       -0.012664
# Region_Code                    -0.022001       -0.016349
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(data.corr(),annot = True)
plt.show()

# %%
plt.figure(figsize  = (12,10))
sns.pairplot(data)
plt.show()

# %%
data.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  127037.000000  127037.000000    127037.000000  127037.000000
# mean   444628.000000      38.765903         0.998134      26.459866
# std     36672.567411      15.465814         0.043152      13.209916
# min    381110.000000      20.000000         0.000000       0.000000
# 25%    412869.000000      25.000000         1.000000      15.000000
# 50%    444628.000000      36.000000         1.000000      28.000000
# 75%    476387.000000      49.000000         1.000000      35.000000
# max    508146.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel        Vintage
# count       127037.000000   127037.000000         127037.000000  127037.000000
# mean             0.460039    30524.643576            111.800468     154.318301
# std              0.498403    16945.297103             54.371765      83.661588
# ...

# %% [markdown]
# # categorical data analysis

# %%
sns.countplot(data.Gender)
plt.show()

# %%
sns.countplot(data.Vehicle_Age)
plt.show()

# %%
sns.countplot(data.Vehicle_Damage)
plt.show()

# %%
sns.countplot(data['Driving_License'])
plt.show()

# %%
sns.countplot(data['Previously_Insured'])
plt.show()

# %%
data.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1         11.0                   1
# 1  381111   Male   40                1         28.0                   0
# 2  381112   Male   47                1         28.0                   0
# 3  381113   Male   24                1         27.0                   1
# 4  381114   Male   27                1         28.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                 152.0       53
# 1    1-2 Year            Yes         33762.0                   7.0      111
# 2    1-2 Year            Yes         40050.0                 124.0      199
# 3    < 1 Year            Yes         37356.0                 152.0      187
# 4    < 1 Year             No         59097.0                 152.0      297

# %%
sns.pairplot(data[['Annual_Premium','Policy_Sales_Channel','Vintage']])

# %%
sns.jointplot(x = 'Annual_Premium',y = 'Policy_Sales_Channel',data= data,kind = 'kde')
plt.show()

# %%
gender = {'Male' :0,'Female':1}
age = {'<1 Year':0,''}
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       381110    Male   25                1         11.0                   1
# 1       381111    Male   40                1         28.0                   0
# 2       381112    Male   47                1         28.0                   0
# 3       381113    Male   24                1         27.0                   1
# 4       381114    Male   27                1         28.0                   1
# ...        ...     ...  ...              ...          ...                 ...
# 127032  508142  Female   26                1         37.0                   1
# 127033  508143  Female   38                1         28.0                   0
# 127034  508144    Male   21                1         46.0                   1
# 127035  508145    Male   71                1         28.0                   1
# 127036  508146    Male   41                1         29.0                   1
#
# ...

# %%
sns.boxplot('Previously_Insured','Gender',data = data)
plt.show()

# %%
sns.violinplot('Previously_Insured','Gender',data=data)
plt.show()

# %%
sns.violinplot('Previously_Insured','Age',data=data)
plt.show()

# %%
sns.violinplot('Age','Vehicle_Damage',data=data)
plt.show()

# %%
plt.figure(figsize = (12,12))
sns.violinplot('Age','Vehicle_Damage','Vehicle_Age',data=data)

plt.show()

# %%
plt.figure(figsize = (16,10))
sns.pointplot('Age','Previously_Insured',data = data)
plt.show()

# %%
import pandas as pd

# %%
data = pd.read_csv("C:/Users/Arun Ahirwar/Desktop/New folder/Untitled form.csv")

# %%
data.head()
# Out:
#                         Timestamp Enrollment number  Roll number  \
# 0  2020/10/01 8:38:45 PM GMT+5:30      208237200012    208230273
# 1  2020/10/01 8:44:29 PM GMT+5:30      178237200047    178230142
# 2  2020/10/01 8:48:37 PM GMT+5:30      198237200030    198230046
# 3  2020/10/01 9:07:22 PM GMT+5:30      198237200032    198230011
# 4  2020/10/01 9:10:13 PM GMT+5:30       20823700011    208230828
#
#                Name            Father's name           Mother's name  Gender  \
# 0  Sanjana chaudhari       Brijlal chaudhari  Suneeta devi chaudhari  Female
# 1  Ramashankar patel        Ramrangile patel        Shakuntala patel    Male
# 2   Jaykumar Khalote  Manmohan Singh Khalote           Babli Khalote    Male
# 3       Amit malakar      Mr. Sanjay malakar      Mrs. Rekha malakar    Male
# 4   Vaishali darbar         Pyarsingh darbar         Santosh darbar   Female
#
#    Contact number                       Email id  \
# 0      8305163181    Pihuchaudhary2002@gmail.com
# ...

# %%
data.to_excel("C:/Users/Arun Ahirwar/Desktop/New folder/Untitled form.xlsx")
